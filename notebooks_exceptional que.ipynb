# %%
#Create a function that converts string input into float and prints half of it. Use else block
#for output and finally block for completion message.

def half_of_input(value):
    try:
        num = float(value)
    except ValueError:
        print("Invalid input. Please enter a number.")
    else:
        print("Half:", num / 2)
    finally:
        print("Conversion completed.")

# %%
#Create a function that converts string input into float and prints half of it. Use else block
#for output and finally block for completion message.

def converter(string):
    try:
        data=float(string)
    except:
        print("ur input is not in digits ,reinitialize using only digits")
    else:
        print(data/2)
    finally:
        print("code is complete")

converter("10.62")
# Out:
# 5.31
# code is complete

# %%
#Create a function that returns absolute value after converting input safely. Use else
#lock to print absolute value and finally block to print Absolute check completed
def absolute(num):
    try:
        abs(num)
    except:
        print("the input is not in digit format")
    else:
        print(abs(num))
    finally:
        print("absolute check complete ")
absolute([1,2,3,4])
# Out:
# the input is not in digit format
# absolute check complete

# %%
def absolute(num):
    try:
        abs(num)
    except:
        print("the input is not in digit format")
        count=1
    else:
        print(abs(num))
        count=0
    finally:
        if count==0:
            print("absolute check complete ")
        elif count==1:
            print("unsuccessful")
        print("absolute check complete ")
absolute([1,2,3,4])
# Out:
# the input is not in digit format
# unsuccessful
# absolute check complete
