# %%
def find_root(string):
    try:
        number=float(string)
    except:
        print("the input is not in digit format")
        new=input("enter ur number again")
        find_root(new)
    else:
        print("root=",number**0.5)
    finally:
        print("squre root opretion finished")
        
find_root("hundred")
# Out:
# the input is not in digit format
# enter ur number again 100
# root= 10.0
# squre root opretion finished
# squre root opretion finished

# %%
#abstraction
#hiding unnecessary implemantation details

# %%
from abc import ABC,abstractmethod

class vechile(ABC):
    @abstrctmethod
    def move(self):
        pass
class car(vechile):
    def move(self):
        print("car is moving")
class bike(vechile):
    def move(self):
        print("bike is running")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 from abc import ABC,abstractmethod
# ----> 3 class vechile(ABC):
#       4     @abstrctmethod
#       5     def move(self):
#       6         pass
#
# Cell In[5], line 4, in vechile()
#       3 class vechile(ABC):
# ----> 4     @abstrctmethod
#       5     def move(self):
#       6         pass
#
# NameError: name 'abstrctmethod' is not defined

# %%
from abc import ABC,abstractmethod
electric_flow=False
class fan():
    @abstractmethod
    def start(self):
        print("switch on .....")
        print("electricity flowing...")
        print("motor running...")
        print("fan rotates...")
        print("fan start...")
Fan1=myfan()        
Fan1.start()
