# %%
import pandas as pd

# %%
data = {
    "Duration": [60, 60, 60, 45, 45, 60, 60, 45, 30, 60],
    "Pulse": [117, 102, 110, 104, 98, 100, 103, 109, 109, 98],
    "Maxpulse": [145, 127, 130, 134, 128, 141, 135, 175, 139, 124],
    "Calories": [479, 340, 282, 406, 300, 374, 253, 282, 195, 269]
}

df = pd.DataFrame(data)

print(df)
print("\nCorrelation:")
print(df.corr())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    117       145       479
# 1        60    102       127       340
# 2        60    110       130       282
# 3        45    104       134       406
# 4        45     98       128       300
# 5        60    100       141       374
# 6        60    103       135       253
# 7        45    109       175       282
# 8        30    109       139       195
# 9        60     98       124       269
#
# Correlation:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.102564 -0.278730  0.401502
# Pulse    -0.102564  1.000000  0.484891  0.279930
# Maxpulse -0.278730  0.484891  1.000000  0.054362
# Calories  0.401502  0.279930  0.054362  1.000000

# %%
! pip install pandas

# %%
! pip install matplotlib pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ----------------------- ---------------- 5.5/9.5 MB 29.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 26.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 14.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------- ----------- 5.2/7.2 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 24.7 MB/s  0:00:00
# ...
#
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
# ...

# %%
import matplotlib.pyplot as plt
"""
library name=matplotlib-open soutce python library used to
 create statistics,
animated and interactive data represtation/visulisation.
pyplot= provides the functions to create and modify the plots .it is a submodul.
"""
# Out:
# '\nlibrary name=matplotlib-open soutce python library used to\n create statistics,\nanimated and interactive data represtation/visulisation.\npyplot= provides the functions to create and modify the plots .it is a submodul.\n'
